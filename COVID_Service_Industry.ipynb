# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
import datetime as dt
import json as json

# %matplotlib inline

# %%
unemployment = pd.read_csv('Data/Unemployment Rate.csv')
hires = pd.read_csv('Data/Hires.csv')
openings = pd.read_csv('Data/Job Openings.csv')

# %%
unemployment
# Out:
#     Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0   2011  13.7  13.6  12.5  11.7  10.6  11.2  11.5  10.6  11.6  10.9  11.2
# 1   2012  12.1  11.8  11.2  10.0   9.7  10.0   9.9  10.8   9.7  10.2  10.4
# 2   2013  12.2  11.3  10.7   9.7  10.8  11.2  10.7   9.8   8.9   8.9   8.7
# 3   2014   9.4  10.3  10.3   8.1   8.4   8.6   8.0   7.9   8.0   8.8   8.3
# 4   2015   9.5   8.5   8.2   7.6   8.2   7.9   8.4   7.8   7.8   8.2   7.3
# 5   2016   7.7   6.9   7.4   6.9   6.7   6.8   6.2   6.8   6.6   6.6   7.2
# 6   2017   8.0   7.0   6.3   5.9   6.3   6.7   5.2   5.5   5.0   5.8   6.6
# 7   2018   6.7   6.7   5.7   5.5   5.1   6.1   5.2   5.8   5.3   5.3   5.3
# 8   2019   6.3   6.1   5.7   4.4   5.0   5.2   5.7   4.8   4.7   5.4   4.8
# 9   2020   6.2   5.9   7.9  37.3  33.9  26.6  23.9  20.8  18.0  15.9  14.6
# 10  2021  15.3  12.7  12.7  10.7   9.9   NaN   NaN   NaN   NaN   NaN   NaN
#
#      Dec
# 0   10.5
# 1   10.9
# 2    8.7
# 3    7.7
# 4    7.3
# ...

# %%
hires
# Out:
#     Year  Jan  Feb  Mar   Apr     May     Jun     Jul     Aug     Sep     Oct  \
# 0   2011  448  469  654   657   663.0   716.0   653.0   660.0   639.0   597.0
# 1   2012  523  508  716   713   741.0   708.0   678.0   726.0   649.0   626.0
# 2   2013  577  560  689   829   817.0   779.0   715.0   714.0   718.0   657.0
# 3   2014  588  600  720   814   890.0   885.0   781.0   773.0   791.0   731.0
# 4   2015  633  639  767   907   958.0   913.0   897.0   965.0   878.0   839.0
# 5   2016  678  764  860   969  1037.0  1013.0   942.0   966.0   846.0   802.0
# 6   2017  759  710  871   937  1008.0  1006.0   912.0   933.0   833.0   849.0
# 7   2018  722  721  837   968  1085.0  1014.0  1017.0   973.0   893.0   901.0
# 8   2019  831  747  917  1111  1083.0  1179.0  1092.0  1076.0   995.0   925.0
# 9   2020  812  757  540   510  1970.0  2124.0  1291.0  1010.0  1000.0  1016.0
# 10  2021  682  894  980  1372     NaN     NaN     NaN     NaN     NaN     NaN
#
#       Nov    Dec
# ...

# %%
openings
# Out:
#     Year  Jan  Feb   Mar   Apr    May    Jun    Jul    Aug    Sep    Oct  \
# 0   2011  302  347   371   367  287.0  336.0  314.0  355.0  353.0  394.0
# 1   2012  342  330   424   490  396.0  421.0  455.0  377.0  358.0  452.0
# 2   2013  368  476   482   529  428.0  448.0  489.0  447.0  469.0  467.0
# 3   2014  446  492   553   683  634.0  605.0  611.0  648.0  616.0  610.0
# 4   2015  650  652   664   769  653.0  606.0  748.0  673.0  620.0  700.0
# 5   2016  604  675   738   782  680.0  705.0  713.0  750.0  656.0  628.0
# 6   2017  586  790   684   896  809.0  745.0  820.0  837.0  665.0  697.0
# 7   2018  773  779   862   994  879.0  921.0  998.0  929.0  966.0  884.0
# 8   2019  959  865   946  1045  934.0  855.0  921.0  860.0  861.0  815.0
# 9   2020  706  787   542   433  661.0  818.0  830.0  757.0  763.0  770.0
# 10  2021  581  804  1019  1470    NaN    NaN    NaN    NaN    NaN    NaN
#
#       Nov    Dec
# 0   324.0  306.0
# 1   386.0  311.0
# 2   404.0  387.0
# 3   513.0  492.0
# ...

# %%
unemployment.plot.bar(x='Year', y='Apr', legend=False)
plt.title('Unemployment Rate')
plt.xlabel('Year')
plt.ylabel('Rate')
# Out:
# Text(0, 0.5, 'Rate')

# %%
hires.plot.bar(x='Year', y='Apr', legend = False)
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
openings.plot.bar(x='Year', y='Apr', legend=False)
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
json.load(r'C:\Users\zrgra\Documents\yelp_academic_dataset_covid_features.json')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-d4e8dee52d43> in <module>
# ----> 1 json.load(r'C:\Users\zrgra\Documents\yelp_academic_dataset_covid_features.json')
#
# ~\Anaconda3\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# AttributeError: 'str' object has no attribute 'read'
